# %% [markdown]
# # 1. Хочу устроить соревы
# # 2. много команд 10+-
# # 3. в каждой команде 3-4 человека, хорошо чтобы вводили телефон для доступа
# # 4. у каждой команды пул из 5-8 компаний, компании могут быть 2 типов холод/горячии
# # 5. есть список вопросов пока хз какой, за каждюу продажу кол-во баллов хз сколько, # + за разный тип компании разное кол-во балов
# # 6. Нужно хранить ответы, еще хорошо чтобы оно само считало балы
# # 7. Выводить все команды от большего кол-ва балов к меньшему
